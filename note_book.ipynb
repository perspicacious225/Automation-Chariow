# %%
import pandas as pd

# %%
df = pd.read_csv("sales_2025-08-30_10-38-20.csv")
df.head()
# Out:
#                   Date              Sale ID         Customer Name  \
# 0  2025-08-30 01:04:29  SALEVZBOZC5JEUSR4C8        Ibrahim TRAORE
# 1  2025-08-30 01:25:37  SALE4U79QLROJR2UZSY          ezaire gnoto
# 2  2025-08-30 03:32:46  SALE6ZRDNDJYAANLDFE      Gabriel Deguenon
# 3  2025-08-30 04:18:31  SALEE76TH58CLQWWDUU  Narcisse Koguedessou
# 4  2025-08-30 06:55:12  SALEQ4K42B4WRIIPDPA    Junior LIBA DILINA
#
#                     Email          Phone Country     Status  Discount Amount  \
# 0  traoremotema@gmail.com  2250708437980      CI  abandoned                0
# 1  gnotoezaire9@gmail.com  2250777461180      CI  completed                0
# 2     degab2017@gmail.com  2290140255745      BJ     failed                0
# 3       knar6t@hotmail.fr  2290196151759      BJ  completed                0
# 4   juniorliba1@gmail.com   237693136349      CM  completed                0
#
#   Discount Amount Formatted  Original Amount Original Amount Formatted  \
# ...
